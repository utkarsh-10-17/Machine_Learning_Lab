# %% [markdown]
# ### Governing Equations
#
# **Newton’s Second Law:**
#
# \[
# \vec{a} =
# \begin{bmatrix}
# -k \cdot v_x \\
# -g - k \cdot v_y
# \end{bmatrix}
# \]
#
# **Position Update:**
#
# \[
# \
# \]
#
# **Velocity Update:**
#
# \[
# \vec{v}_{t+1} = \vec{v}_t + \vec{a} \cdot dt
# \]

# %% [markdown]
# ### Governing Equations
#
# **Newton’s Second Law:**
#
# \[
# \vec{a} =
# \begin{bmatrix}
# -k \cdot v_x \\
# -g - k \cdot v_y
# \end{bmatrix}
# \]
#
# **Position Update:**
#
# \[
# \vec{x}_{t+1} = \vec{x}_t + \vec{v}_t \cdot dt
# \]
#
# **Velocity Update:**
#
# \[
# \vec{v}_{t+1} = \vec{v}_t + \vec{a} \cdot dt
# \]
