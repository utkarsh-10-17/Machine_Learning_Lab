# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('play_tennis.csv')

# %%
data.head()
data.drop(columns=['day'],inplace = True)

# %%
data
# Out:
#      outlook  temp humidity    wind play
# 0      Sunny   Hot     High    Weak   No
# 1      Sunny   Hot     High  Strong   No
# 2   Overcast   Hot     High    Weak  Yes
# 3       Rain  Mild     High    Weak  Yes
# 4       Rain  Cool   Normal    Weak  Yes
# 5       Rain  Cool   Normal  Strong   No
# 6   Overcast  Cool   Normal  Strong  Yes
# 7      Sunny  Mild     High    Weak   No
# 8      Sunny  Cool   Normal    Weak  Yes
# 9       Rain  Mild   Normal    Weak  Yes
# 10     Sunny  Mild   Normal  Strong  Yes
# 11  Overcast  Mild     High  Strong  Yes
# 12  Overcast   Hot   Normal    Weak  Yes
# 13      Rain  Mild     High  Strong   No

# %%
data['play'].value_counts()
# Out:
# play
# Yes    9
# No     5
# Name: count, dtype: int64

# %%
py = 9/14
pn = 5/14

# %%
print(py)
print(pn)
# Out:
# 0.6428571428571429
# 0.35714285714285715

# %%
pd.crosstab(data['outlook'],data['play'])
# Out:
# play      No  Yes
# outlook
# Overcast   0    4
# Rain       2    3
# Sunny      3    2

# %%
pd.crosstab(data['temp'],data['play'])
# Out:
# play  No  Yes
# temp
# Cool   1    3
# Hot    2    2
# Mild   2    4

# %%
pd.crosstab(data['humidity'],data['play'])
# Out:
# play      No  Yes
# humidity
# High       4    3
# Normal     1    6

# %%
pd.crosstab(data['wind'],data['play'])
# Out:
# play    No  Yes
# wind
# Strong   3    3
# Weak     2    6

# %%
pon = 0
prn = 2/5
psn = 3/5

poy = 4/9
pry = 3/9
psy = 2/9

# %%
p_cool_no = 1/5
p_mild_no = 2/5
p_hot_no = 2/5

p_cool_yes = 3/9
p_mild_yes = 4/9
p_hot_yes = 2/9

p_high_no = 4/5
p_normal_no = 1/5

p_high_yes = 3/9
p_normal_yes = 6/9

# %%
p_strong_no = 3/5
p_weak_no = 2/5

p_strong_yes = 3/9
p_weak_yes = 6/9

# %%
#test data
pyes = py*psy*p_hot_yes*p_high_yes*p_weak_yes
print(pyes)
# Out:
# 0.007054673721340388

# %%
pno = pn*psn*p_hot_no*p_high_no*p_weak_no
print(pno)
# Out:
# 0.02742857142857143

# %% [markdown]
# NO play
